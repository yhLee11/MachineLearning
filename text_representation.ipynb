# %%
from google.colab import drive
drive.mount("/gdrive", force_remount=True)
# Out:
# Mounted at /gdrive

# %%
from gensim.models import Word2Vec, KeyedVectors

loaded_model = Word2Vec.load("/gdrive/MyDrive/ML/ko.bin")

# %%
print(loaded_model.wv.most_similar(positive=['한국','파리'],negative=['서울'], topn=3))
print(loaded_model.wv.most_similar(positive=['컴퓨터','인문학'],negative=['과학'], topn=3))
print(loaded_model.wv.most_similar(positive=['사랑','이별'], topn=3))
print(loaded_model.wv.most_similar(positive=['충청북도','강원도'],negative=['청주'], topn=3))
print(loaded_model.wv.most_similar(positive=['인간'],negative=['사랑'], topn=3))
print(loaded_model.wv.most_similar(positive=['미술','음악'],negative=['물감'], topn=3))
# Out:
# [('프랑스', 0.5448222160339355), ('영국', 0.4882664084434509), ('미국', 0.4670472741127014)]
# [('하드웨어', 0.5899531245231628), ('소프트웨어', 0.5636140704154968), ('인터페이스', 0.5426802635192871)]
# [('슬픔', 0.7795703411102295), ('추억', 0.7069746255874634), ('절망', 0.6897162199020386)]
# [('평창군', 0.6565779447555542), ('화천군', 0.6379052996635437), ('경상북도', 0.6310842633247375)]
# [('내재적', 0.49942755699157715), ('유기체', 0.4942871928215027), ('구조적', 0.47677475214004517)]
# [('예술', 0.6641802787780762), ('성악', 0.6235669255256653), ('연극', 0.6229665279388428)]
